# %% [markdown]
# <a href="https://colab.research.google.com/github/gasu021/RepositorioMIA/blob/main/Practica2_de_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Universidad Tecmilenio
# #Fundamentos de Inteligencia Artificial
# Gabriela Susana Escobar Alfaro
#
#
# ---

# %%
#Hola Mundo
print("Hola Mundo")
# Out:
# Hola Mundo
